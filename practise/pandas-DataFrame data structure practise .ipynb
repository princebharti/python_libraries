# %%
import pandas as pd
import numpy as np 
dataset=pd.read_csv("titanic.csv")

# %%
dataset.head(10)
# Out:
#    Unnamed: 0                                           Name PClass    Age  \
# 0           1                   Allen, Miss Elisabeth Walton    1st  29.00
# 1           2                    Allison, Miss Helen Loraine    1st   2.00
# 2           3            Allison, Mr Hudson Joshua Creighton    1st  30.00
# 3           4  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00
# 4           5                  Allison, Master Hudson Trevor    1st   0.92
# 5           6                             Anderson, Mr Harry    1st  47.00
# 6           7               Andrews, Miss Kornelia Theodosia    1st  63.00
# 7           8                         Andrews, Mr Thomas, jr    1st  39.00
# 8           9   Appleton, Mrs Edward Dale (Charlotte Lamson)    1st  58.00
# 9          10                         Artagaveytia, Mr Ramon    1st  71.00
#
#       Sex  Survived  SexCode
# 0  female         1        1
# 1  female         0        1
# 2    male         0        0
# ...

# %%
dataset.tail(10)
# Out:
#       Unnamed: 0                    Name PClass   Age     Sex  Survived  \
# 1303        1304      Yasbeck, Mr Antoni    3rd  27.0    male         0
# 1304        1305     Yasbeck, Mrs Antoni    3rd  15.0  female         1
# 1305        1306      Youssef, Mr Gerios    3rd   NaN    male         0
# 1306        1307     Zabour, Miss Hileni    3rd   NaN  female         0
# 1307        1308     Zabour, Miss Tamini    3rd   NaN  female         0
# 1308        1309      Zakarian, Mr Artun    3rd  27.0    male         0
# 1309        1310  Zakarian, Mr Maprieder    3rd  26.0    male         0
# 1310        1311        Zenni, Mr Philip    3rd  22.0    male         0
# 1311        1312        Lievens, Mr Rene    3rd  24.0    male         0
# 1312        1313          Zimmerman, Leo    3rd  29.0    male         0
#
#       SexCode
# 1303        0
# 1304        1
# 1305        0
# 1306        1
# 1307        1
# 1308        0
# 1309        0
# 1310        0
# 1311        0
# 1312        0

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'PClass', 'Age', 'Sex', 'Survived', 'SexCode'], dtype='object')

# %%
dataset.index.name="position/offset"

# %%
dataset.head()
# Out:
#                  Unnamed: 0                                           Name  \
# position/offset
# 0                         1                   Allen, Miss Elisabeth Walton
# 1                         2                    Allison, Miss Helen Loraine
# 2                         3            Allison, Mr Hudson Joshua Creighton
# 3                         4  Allison, Mrs Hudson JC (Bessie Waldo Daniels)
# 4                         5                  Allison, Master Hudson Trevor
#
#                 PClass    Age     Sex  Survived  SexCode
# position/offset
# 0                  1st  29.00  female         1        1
# 1                  1st   2.00  female         0        1
# 2                  1st  30.00    male         0        0
# 3                  1st  25.00  female         0        1
# 4                  1st   0.92    male         1        0

# %%
dataset.columns.values[0]='s.no'
dataset=dataset.rename(columns={'s.no':'happy'})

# %%
dataset
# Out:
#                  Unnamed: 0                                              Name  \
# position/offset
# 0                         1                      Allen, Miss Elisabeth Walton
# 1                         2                       Allison, Miss Helen Loraine
# 2                         3               Allison, Mr Hudson Joshua Creighton
# 3                         4     Allison, Mrs Hudson JC (Bessie Waldo Daniels)
# 4                         5                     Allison, Master Hudson Trevor
# 5                         6                                Anderson, Mr Harry
# 6                         7                  Andrews, Miss Kornelia Theodosia
# 7                         8                            Andrews, Mr Thomas, jr
# 8                         9      Appleton, Mrs Edward Dale (Charlotte Lamson)
# 9                        10                            Artagaveytia, Mr Ramon
# 10                       11                         Astor, Colonel John Jacob
# ...

# %%
di={'name':[34,'prince','bharti','rahul','tiwari'],'s.no':[22,45,23,655,44]}
p=pd.DataFrame(di)
p
# Out:
#      name  s.no
# 0      34    22
# 1  prince    45
# 2  bharti    23
# 3   rahul   655
# 4  tiwari    44

# %%
import datetime   # datetime module 

start=datetime.datetime(2017,9,1)
end=datetime.datetime(2017,9,10)
step=datetime.timedelta(days=1)

li=[]

while start<end :
    li.append(start.strftime('%d-%m'))
    start+=step
print(li)
# Out:
# ['01-09', '02-09', '03-09', '04-09', '05-09', '06-09', '07-09', '08-09', '09-09']

# %%
datetime.timedelta?

# %%
dataset.head()
dataset.columns.values[0]='s.no'
dataset.head()
# Out:
#                  s.no                                           Name PClass  \
# position/offset
# 0                   1                   Allen, Miss Elisabeth Walton    1st
# 1                   2                    Allison, Miss Helen Loraine    1st
# 2                   3            Allison, Mr Hudson Joshua Creighton    1st
# 3                   4  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st
# 4                   5                  Allison, Master Hudson Trevor    1st
#
#                    Age     Sex  Survived  SexCode
# position/offset
# 0                29.00  female         1        1
# 1                 2.00  female         0        1
# 2                30.00    male         0        0
# 3                25.00  female         0        1
# 4                 0.92    male         1        0

# %%
dataset.Sex.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of position/offset
# 0       female
# 1       female
# 2         male
# 3       female
# 4         male
# 5         male
# 6       female
# 7         male
# 8       female
# 9         male
# 10        male
# 11      female
# 12      female
# 13        male
# 14        male
# 15      female
# 16        male
# 17        male
# 18        male
# 19      female
# 20        male
# 21        male
# 22        male
# 23      female
# 24        male
# 25        male
# 26        male
# 27      female
# 28      female
# 29        male
#          ...
# 1283    female
# 1284      male
# 1285      male
# 1286      male
# 1287      male
# 1288      male
# 1289      male
# 1290      male
# 1291      male
# 1292      male
# 1293    female
# 1294      male
# 1295      male
# 1296      male
# 1297      male
# 1298      male
# 1299      male
# 1300      male
# 1301      male
# 1302      male
# 1303      male
# 1304    female
# 1305      male
# 1306    female
# ...
